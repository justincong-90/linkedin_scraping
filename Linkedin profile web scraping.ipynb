# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os,random,sys,time

# %%
from selenium import webdriver

# %%
from bs4 import BeautifulSoup

# %%
browser = webdriver.Chrome('chromedriver.exe')

# %%
browser.get('https://www.linkedin.com/login')

# %%
info = []
with open('secret.txt','r') as f:
    for line in f.readlines():
        info.append(line)
username = str(info[0])
password = info[1]

# %%
elementID = browser.find_element_by_id('username') ##locate user name

# %%
elementID.send_keys(username) ##fill username

# %%
elementID= browser.find_element_by_id('password')## locate password

# %%
elementID.send_keys(password)## fill password

# %%
elementID.submit()

# %%
import pandas as pd

# %%
df = pd.read_excel('facebook_testset.xlsx')

# %%
linkedin_links = df[['linkedin']]

# %%
import numpy as np

# %%
linkedin_links = np.array(df['linkedin'])

# %%
browser.get(linkedin_links[0])

# %%
source  = browser.page_source
soup = BeautifulSoup(source,'lxml')
soup
# Out:
# <html class="theme theme--mercado artdeco windows" lang="en"><head>
# <script async="" src="https://platform.linkedin.com/js/analytics.js"></script><script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>Yavor A. | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static-exp1.licdn.com/sc/h/brlx1tn7p1njjhu3u6kjxqodw" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="false" name="is-http2"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#0077B5" name="theme-color"/>
# ...

# %%
name_li = soup.find('div',{'class':'flex-1 mr5 pv-top-card__list-container'})

# %%
name_loc = name_li.find_all('ul')

# %%
name_loc[0]
# Out:
# <ul class="pv-top-card--list inline-flex align-items-center">
# <li class="inline t-24 t-black t-normal break-words">
#               Yavor A.
#             </li>
# <li class="pv-top-card__distance-badge inline-block v-align-text-bottom t-16 t-black--light t-normal"><span class="distance-badge separator">
# <span class="visually-hidden">3rd degree connection</span><span aria-hidden="true" class="dist-value">3rd</span>
# </span></li>
# <!-- --><!-- -->
# <!-- --> </ul>
